# %%
import os
import csv
import cv2
import json

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
# Path to the directory containing the images
image_dir = 'for_anotation'
# Output path
output_path = 'data/'

# Path to the CSV file containing the region annotations
annotations_file = 'for_annotation_labels/Garden_Anotation_csv.csv'

# Read the CSV file
with open(annotations_file, 'r') as file:
    csv_reader = csv.DictReader(file)
    annotations = list(csv_reader)

# Create the output directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Extract SIFT features and create feature vectors
features = []
labels = []

# Iterate over the regions
for region in annotations:
    # Get the filename and shape attributes for the region
    filename = region['filename']
    print('File Name: '+filename)
    region_id = region['region_id']
    print('region_id: '+region_id)
    
    updated_filename = filename[:-4] + "_"+region_id+ filename[-4:]
    print('Updated Filename: '+updated_filename)

    shape_attributes = region['region_shape_attributes']
    print('Shape Attributes: '+shape_attributes)
    name = region['region_attributes']
    print('Name Attributes: '+name)
    
     # Parse the shape attributes as a JSON object
    name = json.loads(name)
    image_label = name['name']
    print('Image Label: '+image_label)
    
    # Construct the full path to the image file
    image_path = os.path.join(image_dir, filename)

    # Read the image using OpenCV
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Parse the shape attributes as a JSON object
    shape_attributes = json.loads(shape_attributes)

    # Extract the region from the image using shape attributes
    if shape_attributes['name'] == 'rect':
        x = shape_attributes['x']
        y = shape_attributes['y']
        width = shape_attributes['width']
        height = shape_attributes['height']
        
        roi = gray[y:y+height, x:x+width]

        sift = cv2.SIFT_create()
        _, descriptors = sift.detectAndCompute(roi, None)
        if descriptors is not None:
            features.append(descriptors)
            labels.append(image_label)

# Convert features and labels to numpy arrays
features = np.concatenate(features)
labels = np.array(labels)
# Out:
# File Name: garden_image_05.png
# region_id: 0
# Updated Filename: garden_image_05_0.png
# Shape Attributes: {"name":"rect","x":475,"y":1382,"width":688,"height":1105}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_05.png
# region_id: 1
# Updated Filename: garden_image_05_1.png
# Shape Attributes: {"name":"rect","x":543,"y":407,"width":839,"height":538}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_05.png
# region_id: 2
# Updated Filename: garden_image_05_2.png
# Shape Attributes: {"name":"rect","x":1333,"y":1280,"width":441,"height":335}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_10.png
# region_id: 0
# Updated Filename: garden_image_10_0.png
# Shape Attributes: {"name":"rect","x":756,"y":242,"width":1396,"height":2017}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_11.png
# region_id: 0
# Updated Filename: garden_image_11_0.png
# Shape Attributes: {"name":"rect","x":19,"y":393,"width":1658,"height":1857}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_15.png
# region_id: 0
# Updated Filename: garden_image_15_0.png
# Shape Attributes: {"name":"rect","x":1469,"y":1251,"width":669,"height":776}
# Name Attributes: {"name":"Cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: Cassava
# File Name: garden_image_15.png
# region_id: 1
# Updated Filename: garden_image_15_1.png
# Shape Attributes: {"name":"rect","x":315,"y":931,"width":553,"height":766}
# Name Attributes: {"name":"Sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: Sugarcane
# File Name: garden_image_15.png
# region_id: 2
# Updated Filename: garden_image_15_2.png
# Shape Attributes: {"name":"rect","x":819,"y":1838,"width":339,"height":407}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image

# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_157.png
# region_id: 0
# Updated Filename: garden_image_157_0.png
# Shape Attributes: {"name":"rect","x":112,"y":798,"width":1086,"height":1423}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_157.png
# region_id: 1
# Updated Filename: garden_image_157_1.png
# Shape Attributes: {"name":"rect","x":1151,"y":17,"width":617,"height":1660}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_157.png
# region_id: 2
# Updated Filename: garden_image_157_2.png
# Shape Attributes: {"name":"rect","x":1531,"y":1832,"width":608,"height":918}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_157.png
# region_id: 3
# Updated Filename: garden_image_157_3.png
# Shape Attributes: {"name":"rect","x":668,"y":448,"width":332,"height":444}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_157.png
# region_id: 4
# Updated Filename: garden_image_157_4.png
# Shape Attributes: {"name":"rect","x":776,"y":1966,"width":483,"height":638}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_157.png
# region_id: 5
# Updated Filename: garden_image_157_5.png
# Shape Attributes: {"name":"rect","x":112,"y":2354,"width":543,"height":511}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_157.png
# region_id: 6
# Updated Filename: garden_image_157_6.png
# Shape Attributes: {"name":"rect","x":1802,"y":1177,"width":351,"height":489}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_157.png
# region_id: 7
# Updated Filename: garden_image_157_7.png
# Shape Attributes: {"name":"rect","x":11,"y":1772,"width":280,"height":567}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_157.png
# region_id: 8
# Updated Filename: garden_image_157_8.png
# Shape Attributes: {"name":"rect","x":26,"y":220,"width":556,"height":556}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_158.png
# region_id: 0
# Updated Filename: garden_image_158_0.png
# Shape Attributes: {"name":"rect","x":1122,"y":2671,"width":559,"height":902}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_158.png
# region_id: 1
# Updated Filename: garden_image_158_1.png
# Shape Attributes: {"name":"rect","x":511,"y":2069,"width":482,"height":702}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_158.png
# region_id: 2
# Updated Filename: garden_image_158_2.png
# Shape Attributes: {"name":"rect","x":957,"y":2034,"width":411,"height":517}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_158.png
# region_id: 3
# Updated Filename: garden_image_158_3.png
# Shape Attributes: {"name":"rect","x":1736,"y":2454,"width":317,"height":556}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_158.png
# region_id: 4
# Updated Filename: garden_image_158_4.png
# Shape Attributes: {"name":"rect","x":23,"y":1979,"width":391,"height":669}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_158.png
# region_id: 5
# Updated Filename: garden_image_158_5.png
# Shape Attributes: {"name":"rect","x":511,"y":1177,"width":611,"height":776}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_158.png
# region_id: 6
# Updated Filename: garden_image_158_6.png
# Shape Attributes: {"name":"rect","x":1552,"y":999,"width":605,"height":844}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_158.png
# region_id: 7
# Updated Filename: garden_image_158_7.png
# Shape Attributes: {"name":"rect","x":787,"y":910,"width":261,"height":254}
# Name Attributes: {"name":"coffeetree","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: coffeetree
# File Name: garden_image_158.png
# region_id: 8
# Updated Filename: garden_image_158_8.png
# Shape Attributes: {"name":"rect","x":1112,"y":1108,"width":293,"height":498}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_158.png
# region_id: 9
# Updated Filename: garden_image_158_9.png
# Shape Attributes: {"name":"rect","x":15,"y":267,"width":297,"height":1446}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_160.png
# region_id: 0
# Updated Filename: garden_image_160_0.png
# Shape Attributes: {"name":"rect","x":834,"y":162,"width":1313,"height":3622}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_160.png
# region_id: 1
# Updated Filename: garden_image_160_1.png
# Shape Attributes: {"name":"rect","x":162,"y":2270,"width":666,"height":892}
# Name Attributes: {"name":"corn","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn
# File Name: garden_image_160.png
# region_id: 2
# Updated Filename: garden_image_160_2.png
# Shape Attributes: {"name":"rect","x":275,"y":747,"width":252,"height":947}
# Name Attributes: {"name":"banana","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: banana
# File Name: garden_image_160.png
# region_id: 3
# Updated Filename: garden_image_160_3.png
# Shape Attributes: {"name":"rect","x":10,"y":1685,"width":291,"height":485}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_160.png
# region_id: 4
# Updated Filename: garden_image_160_4.png
# Shape Attributes: {"name":"rect","x":379,"y":746,"width":338,"height":767}
# Name Attributes: {"name":"banana","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: banana
# File Name: garden_image_161.png
# region_id: 0
# Updated Filename: garden_image_161_0.png
# Shape Attributes: {"name":"rect","x":45,"y":84,"width":1546,"height":3667}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_161.png
# region_id: 1
# Updated Filename: garden_image_161_1.png
# Shape Attributes: {"name":"rect","x":1656,"y":142,"width":459,"height":1843}
# Name Attributes: {"name":"sugarcane","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: sugarcane
# File Name: garden_image_162.png
# region_id: 0
# Updated Filename: garden_image_162_0.png
# Shape Attributes: {"name":"rect","x":537,"y":110,"width":1565,"height":3673}
# Name Attributes: {"name":"cassava","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: cassava
# File Name: garden_image_162.png
# region_id: 1
# Updated Filename: garden_image_162_1.png
# Shape Attributes: {"name":"rect","x":0,"y":485,"width":511,"height":763}
# Name Attributes: {"name":"banana","type":"plant","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: banana
# File Name: garden_image_162.png
# region_id: 2
# Updated Filename: garden_image_162_2.png
# Shape Attributes: {"name":"rect","x":19,"y":2367,"width":265,"height":996}
# Name Attributes: {"name":"corn","type":"unknown","image_quality":{"good":true,"frontal":true,"good_illumination":true}}
# Image Label: corn

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Normalize the feature vectors
X_train = X_train / np.linalg.norm(X_train, axis=1, keepdims=True)
X_test = X_test / np.linalg.norm(X_test, axis=1, keepdims=True)

# Train the KNN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Evaluate the KNN model
accuracy = knn.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Split the dataset into training and testing sets
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
#       4 # Normalize the feature vectors
#       5 X_train = X_train / np.linalg.norm(X_train, axis=1, keepdims=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:443, in indexable(*iterables)
#     424 """Make arrays indexable for cross-validation.
#     425
#     426 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     439     sparse matrix, or dataframe) or `None`.
#     440 """
#     442 result = [_make_indexable(X) for X in iterables]
# --> 443 check_consistent_length(*result)
#     444 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [669448, 97]
